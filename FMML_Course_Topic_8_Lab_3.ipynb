# %% [markdown]
# <a href="https://colab.research.google.com/github/Yaswant2003bethina/FMML_PROJETS_AND_LABS/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 14:15:27--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   162MB/s    in 0.4s
#
# 2024-03-26 14:15:27 (162 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 36516   1405.2883v1  When autonomous agents are executing in the re...    cs
# 2286   1802.00560v1  Model interpretability is a requirement in man...    cs
# 19299   1304.3097v1  We are interested in creating an automated or ...    cs
# 1388   1605.09332v4  Object recognition is an important task for im...    cs
# 22150  1506.00308v1  Models of complex systems are often formalized...  stat
# ...             ...                                                ...   ...
# 24256   1211.0191v1  The paper evaluates the error performance of t...    cs
# 7287   1711.07099v1  This paper investigates, from information theo...  stat
# 24017  1612.02559v2  We consider the problem of data augmentation, ...    cs
# 14383  cs/9912004v1  In this paper, we present a method of estimati...    cs
# 17360  1710.07032v1  We describe SLING, a framework for parsing nat...    cs
#
#                                                    title  year  \
# 36516  The Metrics Matter! On the Incompatibility of ...  2014
# 2286   Interpretable Deep Convolutional Neural Networ...  2018
# 19299  Bayesian Inference for Radar Imagery Based Sur...  2013
# 1388   Parametric Exponential Linear Unit for Deep Co...  2016
# 22150  Automatic Inference for Inverting Software Sim...  2015
# ...                                                  ...   ...
# 24256  Performance Evaluation of Random Set Based Ped...  2012
# 7287   Compression-Based Regularization with an Appli...  2017
# 24017                 AGA: Attribute Guided Augmentation  2016
# 14383  Pronoun Resolution in Japanese Sentences Using...  1999
# 17360      SLING: A framework for frame semantic parsing  2017
#
#                                                 keywords
# 36516  [autonomous, executing, objectives, execution,...
# 2286   [interpretability, requirement, applications, ...
# 19299  [interested, automated, automated, capability,...
# 1388   [recognition, important, improving, understand...
# 22150  [formalized, sequential, simulators, computati...
# ...                                                  ...
# 24256  [evaluates, performance, pedestrian, evaluatio...
# 7287   [investigates, information, theoretic, princip...
# 24017  [augmentation, generating, artificial, specifi...
# 14383  [estimating, referents, demonstrative, sentenc...
# 17360  [framework, transition, bidirectional, transit...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 36516    [autonomous, executing, objectives, execution,...
# 2286     [interpretability, requirement, applications, ...
# 19299    [interested, automated, automated, capability,...
# 1388     [recognition, important, improving, understand...
# 22150    [formalized, sequential, simulators, computati...
#                                ...
# 21522    [regressor, convergence, intrinsic, dimension,...
# 16187    [authorship, attribution, considerable, practi...
# 40793    [regression, nonparametric, computationally, e...
# 21434    [information, scientific, development, directi...
# 987      [formalize, collection, perturbing, according,...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8776 words.
# Out of those 4603 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c278968c-bcc8-418a-bccc-d1c57c83aac5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c278968c-bcc8-418a-bccc-d1c57c83aac5")) {                    Plotly.newPlot(                        "c278968c-bcc8-418a-bccc-d1c57c83aac5",                        [{"x":["incompatibility","execution","surrogates","differences","different","compilation","substrate","autonomous","techniques","attention","automated","replanning","answering","demonstrate","respectively","executing","normalized","compiling","comparison","objectives","conditions","respective","decisions","interpretation","interpretability","requirement","indicates","approaches","structure","classified","displayed","algorithms","contemporary","algorithmic","applications","therefore","interpretable","algorithm","successful","interpretations","explainability","convolutional","clustering","sacrificing","instances","proposing","challenge","technique","interpret","situations","inference","available","surveillance","certainty","capability","computation","producing","interested","parameters","concerned","conclusions","collection","parameter","flexibility","behaviors","improving","performances","activation","understanding","parameterization","activations","improvement","exponential","important","recognition","examination","advantage","component","parametric","summarize","difficult","framework","simulators","intensive","inverting","implement","inversion","computationally","simulator","strategies","analytically","characterize","configurations","statistically","simulations","including","automatic","formalized","approximate","sequential","derivation","iteratively","typically","sophisticated","formulation","requiring","programming","metropolis","probabilistic","implementation","geological","continuous","specifically","adversely","resources","combinatorial","debugging","effectively","corrected","potential","correctly","optimization","inspection","trustworthy","challenging","outperform","generalization","hyperplanes","addressed","iterative","dimensions","significant","subroutine","competitive","performance","distributes","anchoring","scalability","classification","outperforms","experiments","precision","heuristics","classifiers","significantly","consequence","effective","wikipedia","character","languages","taxonomic","leverages","multilingual","selection","information","theoretical","comparisons","evaluated","dimensional","independent","intrinsic","resulting","inconsistencies","obtaining","objective","possibility","otherwise","estimation","candidate","construction","variables","evaluation","estimates","considerable","corresponding","difficulties","especially","associated","polyhedral","computational","degeneracy","distribution","relevance","computing","explosion","application","particular","standpoint","statistical","fundamental","geometric","connection","properties","characterization","analyzing","likelihood","operative","institute","calculation","functions"],"y":[3,38,2,56,732,10,6,49,385,167,122,2,55,553,66,10,28,3,128,22,105,11,56,70,17,36,28,400,359,25,4,621,14,39,434,143,25,783,79,8,3,375,152,11,110,22,165,249,19,52,203,290,38,6,48,144,29,20,264,21,18,81,130,26,32,100,47,34,173,6,23,122,44,352,367,6,97,107,43,18,136,569,3,23,0,70,7,86,9,105,6,53,30,18,44,255,198,6,107,74,14,34,98,24,71,46,111,1,143,122,3,124,171,8,67,40,5,99,7,159,28,318,12,3,257,91,103,2,42,75,49,240,2,110,880,1,0,36,460,253,601,80,35,104,269,18,242,21,56,104,2,34,30,155,722,176,42,153,182,110,39,149,2,30,152,34,13,215,56,78,108,259,67,42,140,27,113,103,2,294,0,195,33,137,9,256,252,1,167,91,66,40,221,31,75,71,2,6,24,230],"type":"bar"},{"x":["incompatibility","execution","surrogates","differences","different","compil ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4603,), (4603, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8083333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>End2You</span> <span style=''>The</span> <span style=''>Imperial</span> <span style=''>Toolkit</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3703703703703703);'>Multimodal</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>Profiling</span> <span style=''>by</span> <span style=''>End</span> <span style=''>to</span> <span style=''>End</span> <span style=''>Learning</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>introduce</span> <span style=''>End2You</span> <span style=''>the</span> <span style=''>Imperial</span> <span style=''>College</span> <span style=''>London</span> <span style=''>toolkit</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3703703703703703);'>multimodal</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>profiling</span> <span style=''>by</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>End2You</span> <span style=''>is</span> <span style=''>an</span> <span style=''>open</span> <span style=''>source</span> <span style=''>toolkit</span> <span style='background-color:rgba(0, 255, 0, 0.43999999999999995);'>implemented</span> <span style=''>in</span> <span style=''>Python</span> <span style=''>and</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Tensorflow</span> <span style=''>It</span> <span style=''>provides</span> <span style='background-color:rgba(0, 255, 0, 0.4823529411764705);'>capabilities</span> <span style=''>to</span> <span style=''>train</span> <span style=''>and</span> <span style=''>evaluate</span> <span style=''>models</span> <span style=''>in</span> <span style=''>an</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>manner</span> <span style=''>ie</span> <span style=''>using</span> <span style=''>raw</span> <span style=''>input</span> <span style=''>It</span> <span style=''>supports</span> <span style=''>input</span> <span style=''>from</span> <span style=''>raw</span> <span style=''>audio</span> <span style=''>visual</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>physiological</span> <span style=''>or</span> <span style=''>other</span> <span style=''>types</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.31392174704276615);'>information</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.32038834951456313);'>combination</span> <span style=''>of</span> <span style=''>those</span> <span style=''>and</span> <span style=''>the</span> <span style=''>output</span> <span style=''>can</span> <span style=''>be</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>arbitrary</span> <span style='background-color:rgba(0, 255, 0, 0.3626834381551362);'>representation</span> <span style=''>for</span> <span style=''>either</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.4465408805031447);'>regression</span> <span style=''>tasks</span> <span style=''>To</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.39478957915831664);'>knowledge</span> <span style=''>this</span> <span style=''>is</span> <span style=''>the</span> <span style=''>first</span> <span style=''>toolkit</span> <span style=''>that</span> <span style=''>provides</span> <span style=''>generic</span> <span style=''>end</span> <span style=''>to</span> <span style=''>end</span> <span style=''>learning</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>profiling</span> <span style='background-color:rgba(0, 255, 0, 0.4823529411764705);' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Manifold</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Optimization</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>Mixture</span> <span style=''>Models</span> <br/><br/><span style=''>We</span> <span style=''>take</span> <span style=''>a</span> <span style=''>new</span> <span style=''>look</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>for</span> <span style=''>Gaussian</span> <span style=''>Mixture</span> <span style=''>Models</span> <span style=''>(GMMs)</span> <span style=''>In</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>using</span> <span style=''>emphRiemannian</span> <span style=''>manifold</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>as</span> <span style=''>a</span> <span style=''>powerful</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>counterpart</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Expectation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Maximization</span> <span style=''>(EM)</span> <span style=''>An</span> <span style=''>out</span> <span style=''>of</span> <span style=''>the</span> <span style=''>box</span> <span style=''>invocation</span> <span style=''>of</span> <span style=''>manifold</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>however</span> <span style=''>fails</span> <span style=''>spectacularly</span> <span style=''>it</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>converges</span> <span style=''>to</span> <span style=''>the</span> <span style=''>same</span> <span style=''>solution</span> <span style=''>but</span> <span style=''>vastly</span> <span style=''>slower</span> <span style=''>Driven</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intuition</span> <span style=''>from</span> <span style=''>manifold</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convexity</span> <span style=''>we</span> <span style=''>then</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>reparamerization</span> <span style=''>that</span> <span style=''>has</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>remarkable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consequences</span> <span style=''>It</span> <span style=''>makes</span> <span style=''>manifold</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>optimization</span> <span style=''>not</span> <span style=''>only</span> <span style=''>match</span> <span style=''>EM</span> <span style=''>a</span> <span style=''>highly</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>encouraging</span> <span style=''>result</span> <span style=''>in</span> <span style=''>itself</span> <span style=''>given</span> <span style=''>the</span> <span style=''>poor</span> <span style=''>record</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonlinear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>programming</span> <span style=''>methods</span> <span style=''>have</span> <span style=''>had</span> <span style=''>against</span> <span style=''>EM</span> <span style=''>so</span> <span style=''>far</span> <span style=''>but</span> <span style=''>also</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>outperform</span> <span style=''>EM</span> <span style=''>in</span> <span style=''>many</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>practical</span> <span style=''>settings</span> <span style=''>while</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>displaying</span> <span style= ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Linearized</span> <span style='background-color:rgba(255, 0, 0, 0.3731343283582091);'>Alternating</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Direction</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Minimization</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>with</span> <span style=''>Adaptive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Parameter</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Selection</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>Multiplicative</span> <span style=''>Noise</span> <span style=''>Removal</span> <br/><br/><span style=''>Owing</span> <span style=''>to</span> <span style=''>the</span> <span style=''>edge</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>preserving</span> <span style=''>ability</span> <span style=''>and</span> <span style=''>low</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style=''>cost</span> <span style=''>of</span> <span style=''>the</span> <span style=''>total</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variation</span> <span style=''>(TV)</span> <span style='background-color:rgba(255, 0, 0, 0.6378600823045268);'>variational</span> <span style=''>models</span> <span style=''>with</span> <span style=''>the</span> <span style=''>TV</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style=''>have</span> <span style=''>been</span> <span style=''>widely</span> <span style='background-color:rgba(0, 255, 0, 0.39759036144578314);'>investigated</span> <span style=''>in</span> <span style=''>the</span> <span style=''>field</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>multiplicative</span> <span style=''>noise</span> <span style=''>removal</span> <span style=''>The</span> <span style=''>key</span> <span style=''>points</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successful</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>of</span> <span style=''>these</span> <span style=''>models</span> <span style=''>lie</span> <span style=''>in</span> <span style=''>the</span> <span style=''>optimal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>selection</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parameter</span> <span style=''>which</span> <span style=''>balances</span> <span style=''>the</span> <span style=''>data</span> <span style=''>fidelity</span> <span style=''>term</span> <span style=''>with</span> <span style=''>the</span> <span style=''>TV</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularizer</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>to</span> <span style=''>compute</span> <span style=''>the</span> <span style=''>solution</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>two</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>linearized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>technique</span> <span style=''>which</span> <span style=''>are</span> <span style=''>able</span> <span style=''>to</span> <span style=''>estimate</span> <span style=''>the</span> <span style='backgr ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Differentially</span> <span style=''>Private</span> <span style=''>Dropout</span> <br/><br/><span style=''>Large</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collections</span> <span style=''>required</span> <span style=''>for</span> <span style=''>the</span> <span style=''>training</span> <span style=''>of</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>often</span> <span style=''>contain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>such</span> <span style=''>as</span> <span style=''>the</span> <span style=''>medical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>histories</span> <span style=''>of</span> <span style=''>patients</span> <span style=''>and</span> <span style=''>the</span> <span style=''>privacy</span> <span style=''>of</span> <span style=''>the</span> <span style=''>training</span> <span style=''>data</span> <span style=''>must</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preserved</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>dropout</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>technique</span> <span style=''>that</span> <span style=''>provides</span> <span style=''>an</span> <span style=''>elegant</span> <span style=''>Bayesian</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpretation</span> <span style=''>to</span> <span style=''>dropout</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>intrinsic</span> <span style=''>noise</span> <span style=''>added</span> <span style=''>with</span> <span style=''>the</span> <span style=''>primary</span> <span style=''>goal</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>can</span> <span style=''>be</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploited</span> <span style=''>to</span> <span style=''>obtain</span> <span style=''>a</span> <span style=''>degree</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differential</span> <span style=''>privacy</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterative</span> <span style=''>nature</span> <span style=''>of</span> <span style=''>training</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>presents</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>for</span> <span style=''>privacy</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preserving</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>estimation</span> <span style=''>since</span> <span style=''>multiple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>iterations</span> <span style=''>increase</span> <span style=''>the</span> <span style=''>amount</span> <span style=''>of</span> <span style=''>noise</span> <span style=''>added</span> <span style=''>We</span> <span style=''>overcome</span> <span style=''>this</span> <span style=''>by</span> <span style=''>using</span> <span style=''>a</span> <span style=''>relaxed</span> <span style=''>notion</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differential</span> <span style=''>privacy</span> <span style=''>called</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>concentrated</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>differential</span> <span style=''>privacy</span ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09213802917111348)
# 	automatic (0.07043756670224119)
# 	knowledge (0.12379935965848453)
# 	experimental (0.1344717182497332)
# 	segmentation (0.07257203842049093)
# 	detection (0.12344361437210957)
# 	information (0.2568480967627179)
# 	different (0.26040554962646745)
# 	recognition (0.1305585200996087)
# 	convolutional (0.13340448239060831)
#
# Some Statistics words are:
# 	distributions (0.1231774761186526)
# 	theoretical (0.14881850175967823)
# 	statistical (0.15485168426344897)
# 	estimation (0.17496229260935142)
# 	algorithm (0.38712921065862244)
# 	variables (0.1518350930115636)
# 	distribution (0.1870286576168929)
# 	inference (0.1950729009552539)
# 	regression (0.17345399698340874)
# 	dimensional (0.1925590749120161)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="92b55444-9822-497c-b9b6-8f683289b645" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("92b55444-9822-497c-b9b6-8f683289b645")) {                    Plotly.newPlot(                        "92b55444-9822-497c-b9b6-8f683289b645",                        [{"x":["incompatibility","execution","surrogates","differences","different","compilation","substrate","autonomous","techniques","attention","automated","replanning","answering","demonstrate","respectively","executing","normalized","compiling","comparison","objectives","conditions","respective","decisions","interpretation","interpretability","requirement","indicates","approaches","structure","classified","displayed","algorithms","contemporary","algorithmic","applications","therefore","interpretable","algorithm","successful","interpretations","explainability","convolutional","clustering","sacrificing","instances","proposing","challenge","technique","interpret","situations","inference","available","surveillance","certainty","capability","computation","producing","interested","parameters","concerned","conclusions","collection","parameter","flexibility","behaviors","improving","performances","activation","understanding","parameterization","activations","improvement","exponential","important","recognition","examination","advantage","component","parametric","summarize","difficult","framework","simulators","intensive","inverting","implement","inversion","computationally","simulator","strategies","analytically","characterize","configurations","statistically","simulations","including","automatic","formalized","approximate","sequential","derivation","iteratively","typically","sophisticated","formulation","requiring","programming","metropolis","probabilistic","implementation","geological","continuous","specifically","adversely","resources","combinatorial","debugging","effectively","corrected","potential","correctly","optimization","inspection","trustworthy","challenging","outperform","generalization","hyperplanes","addressed","iterative","dimensions","significant","subroutine","competitive","performance","distributes","anchoring","scalability","classification","outperforms","experiments","precision","heuristics","classifiers","significantly","consequence","effective","wikipedia","character","languages","taxonomic","leverages","multilingual","selection","information","theoretical","comparisons","evaluated","dimensional","independent","intrinsic","resulting","inconsistencies","obtaining","objective","possibility","otherwise","estimation","candidate","construction","variables","evaluation","estimates","considerable","corresponding","difficulties","especially","associated","polyhedral","computational","degeneracy","distribution","relevance","computing","explosion","application","particular","standpoint","statistical","fundamental","geometric","connection","properties","characterization","analyzing","likelihood","operative","institute","calculation","functions","presenting","investigation","invariant","manifolds","characterized","riemannian","trajectory","redundant","difficulty","represented","generally","embedding","traditional","functional","phenomena","variability","underlying","euclidean","visualization","accompanying","dimensionality","desirable","linearity","representations","structured","trajectories","constraints","consistent","observations","sequences","retrieval","representation","involving","summaries","transported","semidefinite","hypothesis","integrate","generalizations","tessellated","complexity","numerical","eliminate","universal","randomized","parametrization","rectangular","polynomial","piecewise","determined","furthermore","discriminant","splitting","illustrated","inclusion ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	inverting
# 	anchoring
# 	degeneracy
# 	methodologically
# 	universally
# 	blockmodel
# 	substantive
# 	jackknife
# 	underdamped
# 	gaussianity
# 	sridharan
# 	endogenous
# 	reparametrizations
# 	advantageously
# 	uninformative
# 	recombine
# 	semiparametric
# 	emphsparse
# 	reparameterized
# 	seasonality
# Some words which never appear in Statistics papers:
# 	incompatibility
# 	compilation
# 	substrate
# 	replanning
# 	compiling
# 	displayed
# 	trustworthy
# 	wikipedia
# 	taxonomic
# 	operative
# 	transported
# 	illuminants
# 	dermatologic
# 	constancy
# 	dermoscopic
# 	supplemented
# 	respecting
# 	recognise
# 	interdependencies
# 	algorithmically

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.056888698682481e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7583333333333333
